# %% [markdown]
# ### Part Two: A WeatherAPI alternative

# %% [markdown]
# #### 1. Examine both Open Meteo and Tomorrow and decide which one you'd prefer to use. What drove your decision?

# %% [markdown]
# I looked at both and, to me, the website/documentation for *Tomorrow* just seemed nicer. I think both have most of the functionality I want, but I like a clean-looking website.

# %% [markdown]
# #### 2. What is the URL to the documentation? (You don't use code for this one)

# %% [markdown]
# https://docs.tomorrow.io/reference/welcome

# %% [markdown]
# #### 3. Make a request for the current weather where you are born, or somewhere you've lived.

# %%
import requests

from dotenv import load_dotenv
import os

load_dotenv()

tomorrow_io_key=os.getenv("tomorrow_io_key")

response = requests.get(f"https://api.tomorrow.io/v4/weather/realtime?location=chicago&apikey={tomorrow_io_key}&units=imperial")
data = response.json()
print(data)
# Out:
# {'code': 401001, 'type': 'Invalid Auth', 'message': 'The method requires authentication but it was not presented or is invalid.'}

# %% [markdown]
# #### 4. Print out the country this location is in.

# %%
## I found that the location['name'] only has one value, and it is "Chicago, Cook County, Illinois, United States" for this data. I separated the value for location>name by commas (learned how to do from googling) and returned the last value (in this case, the country).

location_components = data['location']['name'].split(', ')
location_components[-1]
# Out:
# 'United States'

# %% [markdown]
# #### 5. Print out the difference between the current temperature and how warm it feels. Use "It feels ___ degrees colder" or "It feels ___ degrees warmer," not negative numbers.

# %%
print(f"The current actual temperature is {data['data']['values']['temperature']:.1f} degrees F.")
print(f"The current feels-like temperature is {data['data']['values']['temperatureApparent']:.1f} degrees F.")

if data['data']['values']['temperature'] > data['data']['values']['temperatureApparent']:
    print(f"It feels {data['data']['values']['temperature'] - data['data']['values']['temperatureApparent']:.1f} degrees warmer")
elif data['data']['values']['temperatureApparent'] > data['data']['values']['temperature']:
    print(f"It feels {data['data']['values']['temperatureApparent'] - data['data']['values']['temperature']:.1f} degrees colder")
elif data['data']['values']['temperature'] == data['data']['values']['temperatureApparent']:
    print("The feels-like and actual temperatures are the same.")
# Out:
# The current actual temperature is 39.2 degrees F.
# The current feels-like temperature is 30.8 degrees F.
# It feels 8.4 degrees warmer

# %% [markdown]
# #### 6. What's the current temperature at Heathrow International Airport? Use the airport's IATA code to search.

# %%
response = requests.get(f"https://api.tomorrow.io/v4/weather/realtime?location=51.47138888%2C%20-0.45277777&apikey={tomorrow_io_key}&units=imperial")
data = response.json()
data

print(f"The current temperature at Heathrow is {data['data']['values']['temperature']} degrees F.")
# Out:
# The current temperature at Heathrow is 57.7 degrees F.

# %% [markdown]
# #### 7. What URL would I use to request a 3-day forecast at Heathrow?

# %%
response = requests.get(f"https://api.tomorrow.io/v4/weather/forecast?location=51.47138888%20-0.45277777&timesteps=1d&units=imperial&apikey={tomorrow_io_key}")
data = response.json()
data
# Out:
# {'timelines': {'daily': [{'time': '2025-11-11T06:00:00Z',
#     'values': {'altimeterSettingAvg': 29.65,
#      'altimeterSettingMax': 29.71,
#      'altimeterSettingMin': 29.62,
#      'cloudBaseAvg': 0.4,
#      'cloudBaseMax': 1.3,
#      'cloudBaseMin': 0.2,
#      'cloudCeilingAvg': 1.8,
#      'cloudCeilingMax': 6.3,
#      'cloudCeilingMin': 0,
#      'cloudCoverAvg': 91,
#      'cloudCoverMax': 100,
#      'cloudCoverMin': 42,
#      'dewPointAvg': 53,
#      'dewPointMax': 54.7,
#      'dewPointMin': 46.1,
#      'evapotranspirationAvg': 0.001,
#      'evapotranspirationMax': 0.002,
#      'evapotranspirationMin': 0,
#      'evapotranspirationSum': 0.026,
#      'freezingRainIntensityAvg': 0,
#      'freezingRainIntensityMax': 0,
#      'freezingRainIntensityMin': 0,
#      'humidityAvg': 88,
#      'humidityMax': 95,
#      'humidityMin': 83,
#      'iceAccumulationAvg': 0,
#      'iceAccumulationLweAvg': 0,
#      'iceAccumulationLweMax': 0,
#      'iceAccumulationLweMin': 0,
#      'iceAccumulationLweSum': 0,
#      'iceAccumulationMax': 0,
#      'iceAccumulationMin': 0,
#      'iceAccumulationSum': 0,
#      'moonriseTime': '2025-11-11T21:59:50Z',
#      'moonsetTime': '2025-11-11T13:28:55Z',
#      'precipitationProbabilityAvg': 10.6,
#      'precipitationProbabilityMax': 50,
#      'precipitationProbabilityMin': 0,
#      'pressureSeaLevelAvg': 29.66,
#      'pressureSeaLevelMax': 29.74,
#      'pressureSeaLevelMin': 29.61,
#      'pressureSurfaceLevelAvg': 29.58,
#      'pressureSurfaceLevelMax': 29.65,
#      'pressureSurfaceLevelMin': 29.54,
#      'rainAccumulationAvg': 0,
#      'rainAccumulationMax': 0.02,
#      'rainAccumulationMin': 0,
#      'rainAccumulationSum': 0.08,
#      'rainIntensityAvg': 0,
#      'rainIntensityMax': 0.03,
#      'rainIntensityMin': 0,
#      'sleetAccumulationAvg': 0,
#      'sleetAccumulationLweAvg': 0,
#      'sleetAccumulationLweMax': 0,
#      'sleetAccumulationLweMin': 0,
#      'sleetAccumulationLweSum': 0,
#      'sleetAccumulationMax': 0,
#      'sleetAccumulationMin': 0,
#      'sleetIntensityAvg': 0,
#      'sleetIntensityMax': 0,
#      'sleetIntensityMin': 0,
#      'snowAccumulationAvg': 0,
#      'snowAccumulationLweAvg': 0,
#      'snowAccumulationLweMax': 0,
#      'snowAccumulationLweMin': 0,
#      'snowAccumulationLweSum': 0,
#      'snowAccumulationMax': 0,
#      'snowAccumulationMin': 0,
#      'snowAccumulationSum': 0,
#      'snowDepthAvg': None,
#      'snowDepthMax': None,
#      'snowDepthMin': None,
#      'snowDepthSum': None,
#      'snowIntensityAvg': 0,
#      'snowIntensityMax': 0,
#      'snowIntensityMin': 0,
#      'sunriseTime': '2025-11-11T07:04:00Z',
#      'sunsetTime': '2025-11-11T16:27:00Z',
#      'temperatureApparentAvg': 56.4,
#      'temperatureApparentMax': 59.1,
#      'temperatureApparentMin': 47.6,
#      'temperatureAvg': 56.4,
#      'temperatureMax': 59.1,
#      'temperatureMin': 47.6,
#      'uvHealthConcernAvg': 0,
#      'uvHealthConcernMax': 0,
#      'uvHealthConcernMin': 0,
#      'uvIndexAvg': 0,
#      'uvIndexMax': 1,
#      'uvIndexMin': 0,
#      'visibilityAvg': 8.94,
#      'visibilityMax': 9.94,
#      'visibilityMin': 3.92,
#      'weatherCodeMax': 1001,
#      'weatherCodeMin': 1001,
#      'windDirectionAvg': 187,
#      'windGustAvg': 11.7,
#      'windGustMax': 16.4,
#      'windGustMin': 2.7,
#      'windSpeedAvg': 7.2,
#      'windSpeedMax': 10.1,
#      'windSpeedMin': 2.2}},
#    {'time': '2025-11-12T06:00:00Z',
#     'values': {'altimeterSettingAvg': 29.61,
#      'altimeterSettingMax': 29.64,
#      'altimeterSettingMin': 29.59,
#      'cloudBaseAvg': 2,
#      'cloudBaseMax': 5.2,
#      'cloudBaseMin': 0.3,
#      'cloudCeilingAvg': 3.8,
#      'cloudCeilingMax': 7.2,
#      'cloudCeilingMin': 1.4,
#      'cloudCoverAvg': 93,
#      'cloudCoverMax': 100,
#      'cloudCoverMin': 52,
#      'dewPointAvg': 52,
#      'dewPointMax': 53.2,
#      'dewPointMin': 50.5,
#      'evapotranspirationAvg': 0.001,
#      'evapotranspirationMax': 0.003,
#      'evapotranspirationMin': 0.001,
#      'evapotranspirationSum': 0.035,
#      'freezingRainIntensityAvg': 0,
#      'freezingRainIntensityMax': 0,
#      'freezingRainIntensityMin': 0,
#      'humidityAvg': 83,
#      'humidityMax': 89,
#      'humidityMin': 75,
#      'iceAccumulationAvg': 0,
#      'iceAccumulationLweAvg': 0,
#      'iceAccumulationLweMax': 0,
#      'iceAccumulationLweMin': 0,
#      'iceAccumulationLweSum': 0,
#      'iceAccumulationMax': 0,
#      'iceAccumulationMin': 0,
#      'iceAccumulationSum': 0,
#      'moonriseTime': '2025-11-12T23:24:49Z',
#      'moonsetTime': '2025-11-12T13:47:46Z',
#      'precipitationProbabilityAvg': 7.4,
#      'precipitationProbabilityMax': 93,
#      'precipitationProbabilityMin': 0,
#      'pressureSeaLevelAvg': 29.63,
#      'pressureSeaLevelMax': 29.66,
#      'pressureSeaLevelMin': 29.6,
#      'pressureSurfaceLevelAvg': 29.55,
#      'pressureSurfaceLevelMax': 29.58,
#      'pressureSurfaceLevelMin': 29.53,
#      'rainAccumulationAvg': 0,
#      'rainAccumulationMax': 0.02,
#      'rainAccumulationMin': 0,
#      'rainAccumulationSum': 0.03,
#      'rainIntensityAvg': 0,
#      'rainIntensityMax': 0.01,
#      'rainIntensityMin': 0,
#      'sleetAccumulationAvg': 0,
#      'sleetAccumulationLweAvg': 0,
#      'sleetAccumulationLweMax': 0,
#      'sleetAccumulationLweMin': 0,
#      'sleetAccumulationLweSum': 0,
#      'sleetAccumulationMax': 0,
#      'sleetAccumulationMin': 0,
#      'sleetIntensityAvg': 0,
#      'sleetIntensityMax': 0,
#      'sleetIntensityMin': 0,
#      'snowAccumulationAvg': 0,
#      'snowAccumulationLweAvg': 0,
#      'snowAccumulationLweMax': 0,
#      'snowAccumulationLweMin': 0,
#      'snowAccumulationLweSum': 0,
#      'snowAccumulationMax': 0,
#      'snowAccumulationMin': 0,
#      'snowAccumulationSum': 0,
#      'snowDepthAvg': None,
#      'snowDepthMax': None,
#      'snowDepthMin': None,
#      'snowDepthSum': None,
#      'snowIntensityAvg': 0,
#      'snowIntensityMax': 0,
#      'snowIntensityMin': 0,
#      'sunriseTime': '2025-11-12T07:06:00Z',
#      'sunsetTime': '2025-11-12T16:25:00Z',
#      'temperatureApparentAvg': 57.1,
#      'temperatureApparentMax': 60.7,
#      'temperatureApparentMin': 55.2,
#      'temperatureAvg': 57.1,
#      'temperatureMax': 60.7,
#      'temperatureMin': 55.2,
#      'uvHealthConcernAvg': 0,
#      'uvHealthConcernMax': 0,
#      'uvHealthConcernMin': 0,
#      'uvIndexAvg': 0,
#      'uvIndexMax': 1,
#      'uvIndexMin': 0,
#      'visibilityAvg': 9.48,
#      'visibilityMax': 9.94,
#      'visibilityMin': 4.92,
#      'weatherCodeMax': 1001,
#      'weatherCodeMin': 1001,
#      'windDirectionAvg': 188,
#      'windGustAvg': 17.9,
#      'windGustMax': 28.1,
#      'windGustMin': 14.8,
#      'windSpeedAvg': 8.9,
#      'windSpeedMax': 13.4,
#      'windSpeedMin': 7.5}},
#    {'time': '2025-11-13T06:00:00Z',
#     'values': {'altimeterSettingAvg': 29.75,
#      'altimeterSettingMax': 29.79,
#      'altimeterSettingMin': 29.66,
#      'cloudBaseAvg': 1.2,
#      'cloudBaseMax': 4.3,
#      'cloudBaseMin': 0.2,
#      'cloudCeilingAvg': 2.6,
#      'cloudCeilingMax': 5.4,
#      'cloudCeilingMin': 0.2,
#      'cloudCoverAvg': 100,
#      'cloudCoverMax': 100,
#      'cloudCoverMin': 98,
#      'dewPointAvg': 53.3,
#      'dewPointMax': 55.3,
#      'dewPointMin': 51.2,
#      'evapotranspirationAvg': 0.001,
#      'evapotranspirationMax': 0.001,
#      'evapotranspirationMin': 0,
#      'evapotranspirationSum': 0.017,
#      'freezingRainIntensityAvg': 0,
#      'freezingRainIntensityMax': 0,
#      'freezingRainIntensityMin': 0,
#      'humidityAvg': 91,
#      'humidityMax': 96,
#      'humidityMin': 78,
#      'iceAccumulationAvg': 0,
#      'iceAccumulationMax': 0,
#      'iceAccumulationMin': 0,
#      'iceAccumulationSum': 0,
#      'moonriseTime': None,
#      'moonsetTime': '2025-11-13T14:02:02Z',
#      'precipitationProbabilityAvg': 15,
#      'precipitationProbabilityMax': 65,
#      'precipitationProbabilityMin': 0,
#      'pressureSeaLevelAvg': 29.76,
#      'pressureSeaLevelMax': 29.81,
#      'pressureSeaLevelMin': 29.67,
#      'pressureSurfaceLevelAvg': 29.68,
#      'pressureSurfaceLevelMax': 29.73,
#      'pressureSurfaceLevelMin': 29.6,
#      'rainAccumulationAvg': 0.02,
#      'rainAccumulationMax': 0.07,
#      'rainAccumulationMin': 0,
#      'rainAccumulationSum': 0.38,
#      'rainIntensityAvg': 0.02,
#      'rainIntensityMax': 0.07,
#      'rainIntensityMin': 0,
#      'sleetIntensityAvg': 0,
#      'sleetIntensityMax': 0,
#      'sleetIntensityMin': 0,
#      'snowAccumulationAvg': 0,
#      'snowAccumulationMax': 0,
#      'snowAccumulationMin': 0,
#      'snowAccumulationSum': 0,
#      'snowDepthAvg': None,
#      'snowDepthMax': None,
#      'snowDepthMin': None,
#      'snowDepthSum': None,
#      'snowIntensityAvg': 0,
#      'snowIntensityMax': 0,
#      'snowIntensityMin': 0,
#      'sunriseTime': '2025-11-13T07:07:00Z',
#      'sunsetTime': '2025-11-13T16:24:00Z',
#      'temperatureApparentAvg': 56.1,
#      'temperatureApparentMax': 60.9,
#      'temperatureApparentMin': 52.4,
#      'temperatureAvg': 56.1,
#      'temperatureMax': 60.9,
#      'temperatureMin': 52.4,
#      'uvHealthConcernAvg': 0,
#      'uvHealthConcernMax': 0,
#      'uvHealthConcernMin': 0,
#      'uvIndexAvg': 0,
#      'uvIndexMax': 1,
#      'uvIndexMin': 0,
#      'visibilityAvg': 7.13,
#      'visibilityMax': 9.94,
#      'visibilityMin': 1.75,
#      'weatherCodeMax': 1001,
#      'weatherCodeMin': 1001,
#      'windDirectionAvg': 131,
#      'windGustAvg': 13.3,
#      'windGustMax': 22.8,
#      'windGustMin': 1.5,
#      'windSpeedAvg': 6.8,
#      'windSpeedMax': 11.9,
#      'windSpeedMin': 1.1}},
#    {'time': '2025-11-14T06:00:00Z',
#     'values': {'altimeterSettingAvg': 29.67,
#      'altimeterSettingMax': 29.77,
#      'altimeterSettingMin': 29.61,
#      'cloudBaseAvg': 0.2,
#      'cloudBaseMax': 0.2,
#      'cloudBaseMin': 0.1,
#      'cloudCeilingAvg': 0.2,
#      'cloudCeilingMax': 0.2,
#      'cloudCeilingMin': 0.2,
#      'cloudCoverAvg': 100,
#      'cloudCoverMax': 100,
#      'cloudCoverMin': 100,
#      'dewPointAvg': 48.4,
#      'dewPointMax': 51.7,
#      'dewPointMin': 44.7,
#      'evapotranspirationAvg': 0.001,
#      'evapotranspirationMax': 0.001,
#      'evapotranspirationMin': 0.001,
#      'evapotranspirationSum': 0.017,
#      'freezingRainIntensityAvg': 0,
#      'freezingRainIntensityMax': 0,
#      'freezingRainIntensityMin': 0,
#      'humidityAvg': 94,
#      'humidityMax': 96,
#      'humidityMin': 87,
#      'iceAccumulationAvg': 0,
#      'iceAccumulationLweAvg': 0,
#      'iceAccumulationLweMax': 0,
#      'iceAccumulationLweMin': 0,
#      'iceAccumulationLweSum': 0,
#      'iceAccumulationMax': 0,
#      'iceAccumulationMin': 0,
#      'iceAccumulationSum': 0,
#      'moonriseTime': '2025-11-14T00:44:47Z',
#      'moonsetTime': '2025-11-14T14:12:16Z',
#      'precipitationProbabilityAvg': 56.5,
#      'precipitationProbabilityMax': 75,
#      'precipitationProbabilityMin': 0,
#      'pressureSeaLevelAvg': 29.68,
#      'pressureSeaLevelMax': 29.78,
#      'pressureSeaLevelMin': 29.62,
#      'pressureSurfaceLevelAvg': 29.6,
#      'pressureSurfaceLevelMax': 29.71,
#      'pressureSurfaceLevelMin': 29.54,
#      'rainAccumulationAvg': 0.07,
#      'rainAccumulationMax': 0.16,
#      'rainAccumulationMin': 0,
#      'rainAccumulationSum': 1.68,
#      'rainIntensityAvg': 0.07,
#      'rainIntensityMax': 0.16,
#      'rainIntensityMin': 0,
#      'sleetIntensityAvg': 0,
#      'sleetIntensityMax': 0,
#      'sleetIntensityMin': 0,
#      'snowAccumulationAvg': 0,
#      'snowAccumulationLweAvg': 0,
#      'snowAccumulationLweMax': 0,
#      'snowAccumulationLweMin': 0,
#      'snowAccumulationLweSum': 0,
#      'snowAccumulationMax': 0,
#      'snowAccumulationMin': 0,
#      'snowAccumulationSum': 0,
#      'snowDepthAvg': None,
#      'snowDepthMax': None,
#      'snowDepthMin': None,
#      'snowDepthSum': None,
#      'snowIntensityAvg': 0,
#      'snowIntensityMax': 0,
#      'snowIntensityMin': 0,
#      'sunriseTime': '2025-11-14T07:08:00Z',
#      'sunsetTime': '2025-11-14T16:23:00Z',
#      'temperatureApparentAvg': 50.2,
#      'temperatureApparentMax': 52.9,
#      'temperatureApparentMin': 48.2,
#      'temperatureAvg': 50.2,
#      'temperatureMax': 52.9,
#      'temperatureMin': 48.2,
#      'uvHealthConcernAvg': 0,
#      'uvHealthConcernMax': 0,
#      'uvHealthConcernMin': 0,
#      'uvIndexAvg': 0,
#      'uvIndexMax': 0,
#      'uvIndexMin': 0,
#      'visibilityAvg': 3.87,
#      'visibilityMax': 9.94,
#      'visibilityMin': 1.26,
#      'weatherCodeMax': 4001,
#      'weatherCodeMin': 4001,
#      'windDirectionAvg': 60,
#      'windGustAvg': 29.6,
#      'windGustMax': 33.9,
#      'windGustMin': 23.8,
#      'windSpeedAvg': 15.3,
#      'windSpeedMax': 17.7,
#      'windSpeedMin': 11.6}},
#    {'time': '2025-11-15T06:00:00Z',
#     'values': {'altimeterSettingAvg': 29.8,
#      'altimeterSettingMax': 29.85,
#      'altimeterSettingMin': 29.78,
#      'cloudBaseAvg': 0.3,
#      'cloudBaseMax': 0.4,
#      'cloudBaseMin': 0.2,
#      'cloudCeilingAvg': 0.3,
#      'cloudCeilingMax': 0.4,
#      'cloudCeilingMin': 0.2,
#      'cloudCoverAvg': 100,
#      'cloudCoverMax': 100,
#      'cloudCoverMin': 100,
#      'dewPointAvg': 44.8,
#      'dewPointMax': 46.9,
#      'dewPointMin': 43.2,
#      'evapotranspirationAvg': 0.001,
#      'evapotranspirationMax': 0.001,
#      'evapotranspirationMin': 0.001,
#      'evapotranspirationSum': 0.025,
#      'freezingRainIntensityAvg': 0,
#      'freezingRainIntensityMax': 0,
#      'freezingRainIntensityMin': 0,
#      'humidityAvg': 86,
#      'humidityMax': 90,
#      'humidityMin': 83,
#      'iceAccumulationAvg': 0,
#      'iceAccumulationLweAvg': 0,
#      'iceAccumulationLweMax': 0,
#      'iceAccumulationLweMin': 0,
#      'iceAccumulationLweSum': 0,
#      'iceAccumulationMax': 0,
#      'iceAccumulationMin': 0,
#      'iceAccumulationSum': 0,
#      'moonriseTime': '2025-11-15T02:00:01Z',
#      'moonsetTime': '2025-11-15T14:22:10Z',
#      'precipitationProbabilityAvg': 1.3,
#      'precipitationProbabilityMax': 15,
#      'precipitationProbabilityMin': 0,
#      'pressureSeaLevelAvg': 29.82,
#      'pressureSeaLevelMax': 29.87,
#      'pressureSeaLevelMin': 29.79,
#      'pressureSurfaceLevelAvg': 29.74,
#      'pressureSurfaceLevelMax': 29.79,
#      'pressureSurfaceLevelMin': 29.72,
#      'rainAccumulationAvg': 0,
#      'rainAccumulationMax': 0,
#      'rainAccumulationMin': 0,
#      'rainAccumulationSum': 0,
#      'rainIntensityAvg': 0,
#      'rainIntensityMax': 0,
#      'rainIntensityMin': 0,
#      'sleetIntensityAvg': 0,
#      'sleetIntensityMax': 0,
#      'sleetIntensityMin': 0,
#      'snowAccumulationAvg': 0,
#      'snowAccumulationLweAvg': 0,
#      'snowAccumulationLweMax': 0,
#      'snowAccumulationLweMin': 0,
#      'snowAccumulationLweSum': 0,
#      'snowAccumulationMax': 0,
#      'snowAccumulationMin': 0,
#      'snowAccumulationSum': 0,
#      'snowIntensityAvg': 0,
#      'snowIntensityMax': 0,
#      'snowIntensityMin': 0,
#      'sunriseTime': '2025-11-15T07:10:00Z',
#      'sunsetTime': '2025-11-15T16:23:00Z',
#      'temperatureApparentAvg': 48.9,
#      'temperatureApparentMax': 51.3,
#      'temperatureApparentMin': 46,
#      'temperatureAvg': 48.9,
#      'temperatureMax': 51.3,
#      'temperatureMin': 46,
#      'uvHealthConcernAvg': 0,
#      'uvHealthConcernMax': 0,
#      'uvHealthConcernMin': 0,
#      'uvIndexAvg': 0,
#      'uvIndexMax': 0,
#      'uvIndexMin': 0,
#      'visibilityAvg': 9.78,
#      'visibilityMax': 9.94,
#      'visibilityMin': 6.71,
#      'weatherCodeMax': 1001,
#      'weatherCodeMin': 1001,
#      'windDirectionAvg': 44,
#      'windGustAvg': 19.5,
#      'windGustMax': 27,
#      'windGustMin': 15.9,
#      'windSpeedAvg': 9.3,
#      'windSpeedMax': 13.1,
#      'windSpeedMin': 7.9}},
#    {'time': '2025-11-16T06:00:00Z',
#     'values': {'altimeterSettingAvg': 29.88,
#      'altimeterSettingMax': 30,
#      'altimeterSettingMin': 29.78,
#      'cloudBaseAvg': 0.7,
#      'cloudBaseMax': 1.3,
#      'cloudBaseMin': 0.2,
#      'cloudCeilingAvg': 0.9,
#      'cloudCeilingMax': 1.3,
#      'cloudCeilingMin': 0.4,
#      'cloudCoverAvg': 58,
#      'cloudCoverMax': 100,
#      'cloudCoverMin': 0,
#      'dewPointAvg': 37,
#      'dewPointMax': 43.4,
#      'dewPointMin': 31.6,
#      'evapotranspirationAvg': 0.001,
#      'evapotranspirationMax': 0.002,
#      'evapotranspirationMin': 0.001,
#      'evapotranspirationSum': 0.029,
#      'freezingRainIntensityAvg': 0,
#      'freezingRainIntensityMax': 0,
#      'freezingRainIntensityMin': 0,
#      'humidityAvg': 78,
#      'humidityMax': 90,
#      'humidityMin': 67,
#      'iceAccumulationAvg': 0,
#      'iceAccumulationLweAvg': 0,
#      'iceAccumulationLweMax': 0,
#      'iceAccumulationLweMin': 0,
#      'iceAccumulationLweSum': 0,
#      'iceAccumulationMax': 0,
#      'iceAccumulationMin': 0,
#      'iceAccumulationSum': 0,
#      'moonriseTime': '2025-11-16T03:14:15Z',
#      'moonsetTime': '2025-11-16T14:32:13Z',
#      'precipitationProbabilityAvg': 0.6,
#      'precipitationProbabilityMax': 5,
#      'precipitationProbabilityMin': 0,
#      'pressureSeaLevelAvg': 29.89,
#      'pressureSeaLevelMax': 30.01,
#      'pressureSeaLevelMin': 29.79,
#      'pressureSurfaceLevelAvg': 29.82,
#      'pressureSurfaceLevelMax': 29.93,
#      'pressureSurfaceLevelMin': 29.72,
#      'rainAccumulationAvg': 0,
#      'rainAccumulationMax': 0,
#      'rainAccumulationMin': 0,
#      'rainAccumulationSum': 0,
#      'rainIntensityAvg': 0,
#      'rainIntensityMax': 0,
#      'rainIntensityMin': 0,
#      'sleetIntensityAvg': 0,
#      'sleetIntensityMax': 0,
#      'sleetIntensityMin': 0,
#      'snowAccumulationAvg': 0,
#      'snowAccumulationLweAvg': 0,
#      'snowAccumulationLweMax': 0,
#      'snowAccumulationLweMin': 0,
#      'snowAccumulationLweSum': 0,
#      'snowAccumulationMax': 0,
#      'snowAccumulationMin': 0,
#      'snowAccumulationSum': 0,
#      'snowIntensityAvg': 0,
#      'snowIntensityMax': 0,
#      'snowIntensityMin': 0,
#      'sunriseTime': '2025-11-16T07:11:00Z',
#      'sunsetTime': '2025-11-16T16:22:00Z',
#      'temperatureApparentAvg': 41.9,
#      'temperatureApparentMax': 49.4,
#      'temperatureApparentMin': 29.9,
#      'temperatureAvg': 43.7,
#      'temperatureMax': 49.4,
#      'temperatureMin': 36.2,
#      'uvHealthConcernAvg': 0,
#      'uvHealthConcernMax': 0,
#      'uvHealthConcernMin': 0,
#      'uvIndexAvg': 0,
#      'uvIndexMax': 0,
#      'uvIndexMin': 0,
#      'visibilityAvg': 9.94,
#      'visibilityMax': 9.94,
#      'visibilityMin': 9.94,
#      'weatherCodeMax': 1001,
#      'weatherCodeMin': 1001,
#      'windDirectionAvg': 152,
#      'windGustAvg': 17,
#      'windGustMax': 20.6,
#      'windGustMin': 14.5,
#      'windSpeedAvg': 8.2,
#      'windSpeedMax': 9.4,
#      'windSpeedMin': 7.2}},
#    {'time': '2025-11-17T06:00:00Z',
#     'values': {'altimeterSettingAvg': 30.09,
#      'altimeterSettingMax': 30.14,
#      'altimeterSettingMin': 30,
#      'cloudBaseAvg': 4.2,
#      'cloudBaseMax': 4.2,
#      'cloudBaseMin': 4.2,
#      'cloudCeilingAvg': 4.6,
#      'cloudCeilingMax': 4.6,
#      'cloudCeilingMin': 4.6,
#      'cloudCoverAvg': 32,
#      'cloudCoverMax': 97,
#      'cloudCoverMin': 0,
#      'dewPointAvg': 30.6,
#      'dewPointMax': 31.7,
#      'dewPointMin': 30.1,
#      'evapotranspirationAvg': 0.001,
#      'evapotranspirationMax': 0.002,
#      'evapotranspirationMin': 0,
#      'evapotranspirationSum': 0.022,
#      'freezingRainIntensityAvg': 0,
#      'freezingRainIntensityMax': 0,
#      'freezingRainIntensityMin': 0,
#      'humidityAvg': 78,
#      'humidityMax': 89,
#      'humidityMin': 65,
#      'iceAccumulationAvg': 0,
#      'iceAccumulationLweAvg': 0,
#      'iceAccumulationLweMax': 0,
#      'iceAccumulationLweMin': 0,
#      'iceAccumulationLweSum': 0,
#      'iceAccumulationMax': 0,
#      'iceAccumulationMin': 0,
#      'iceAccumulationSum': 0,
#      'moonriseTime': '2025-11-17T04:27:36Z',
#      'moonsetTime': '2025-11-17T14:43:17Z',
#      'precipitationProbabilityAvg': 0,
#      'precipitationProbabilityMax': 0,
#      'precipitationProbabilityMin': 0,
#      'pressureSeaLevelAvg': 30.11,
#      'pressureSeaLevelMax': 30.16,
#      'pressureSeaLevelMin': 30.01,
#      'pressureSurfaceLevelAvg': 30.03,
#      'pressureSurfaceLevelMax': 30.08,
#      'pressureSurfaceLevelMin': 29.93,
#      'rainAccumulationAvg': 0,
#      'rainAccumulationMax': 0,
#      'rainAccumulationMin': 0,
#      'rainAccumulationSum': 0,
#      'rainIntensityAvg': 0,
#      'rainIntensityMax': 0,
#      'rainIntensityMin': 0,
#      'sleetIntensityAvg': 0,
#      'sleetIntensityMax': 0,
#      'sleetIntensityMin': 0,
#      'snowAccumulationAvg': 0,
#      'snowAccumulationLweAvg': 0,
#      'snowAccumulationLweMax': 0,
#      'snowAccumulationLweMin': 0,
#      'snowAccumulationLweSum': 0,
#      'snowAccumulationMax': 0,
#      'snowAccumulationMin': 0,
#      'snowAccumulationSum': 0,
#      'snowIntensityAvg': 0,
#      'snowIntensityMax': 0,
#      'snowIntensityMin': 0,
#      'sunriseTime': '2025-11-17T07:12:00Z',
#      'sunsetTime': '2025-11-17T16:21:00Z',
#      'temperatureApparentAvg': 32.5,
#      'temperatureApparentMax': 41,
#      'temperatureApparentMin': 29.1,
#      'temperatureAvg': 36.9,
#      'temperatureMax': 41,
#      'temperatureMin': 34.1,
#      'visibilityAvg': 9.94,
#      'visibilityMax': 9.94,
#      'visibilityMin': 9.94,
#      'weatherCodeMax': 1000,
#      'weatherCodeMin': 1000,
#      'windDirectionAvg': 301,
#      'windGustAvg': 14,
#      'windGustMax': 18.8,
#      'windGustMin': 8.1,
#      'windSpeedAvg': 6.8,
#      'windSpeedMax': 8.2,
#      'windSpeedMin': 4.1}}]},
#  'location': {'lat': 51.47138595581055,
#   'lon': -0.45277950167655945,
#   'name': 'Heathrow Terminals 2 & 3, Constellation Way, London Borough of Hillingdon, London, Greater London, England, TW6 1SL, United Kingdom',
#   'type': 'stop'}}

# %% [markdown]
# #### 8. Print the date of each of the 3 days you're getting a forecast for.

# %%
for date in data['timelines']['daily'][:3]:
    print(date['time'])
# Out:
# 2025-11-11T06:00:00Z
# 2025-11-12T06:00:00Z
# 2025-11-13T06:00:00Z

# %% [markdown]
# #### 9. Print the maximum temperature of each of the days.

# %%
data['timelines']['daily'][0]['values']['temperatureApparentMax']

for day in data['timelines']['daily'][:3]:
    print(f"The max temperature on the day will be {day['values']['temperatureApparentMax']} degrees F")
# Out:
# The max temperature on the day will be 59.1 degrees F
# The max temperature on the day will be 60.7 degrees F
# The max temperature on the day will be 60.9 degrees F

# %% [markdown]
# #### 10. Print only the day with the highest maximum temperature.

# %%
three_day_highs = [forecast_high['values']['temperatureApparentMax'] for forecast_high in data['timelines']['daily'][:3]]
print(f"The maximum high temp across the three days will be {max(three_day_highs)} degrees F.")
# Out:
# The maximum high temp across the three days will be 60.9 degrees F.

# %% [markdown]
# #### 11. Did you find this easier or more difficult than using the weatherapi.com, and why? Which would you recommend to someone interesting in building a tool around weather information?

# %% [markdown]
# I thought, for a number of reasons, that Weatherapi.com was easier than Tomorrow.io. I think that the search parameters and url construction was more straightforward (and, although both included endpoint builders, Weatherapi's endpoint builder was easier to use). Also, the free tier of Tomorrow.io only allows 25 requests per hour, which gets annoying especially if I am learning how to use it by trying a request and seeing if it works. I would recoomend Weatherapi.com to anyone asking my opinion.
